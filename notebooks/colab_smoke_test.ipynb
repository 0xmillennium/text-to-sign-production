# %% [markdown]
# # Colab Smoke Test
#
# This notebook is runner-only. It installs the repository, imports code from `src/`, and
# executes a package/import smoke check. It must not contain core project logic.
#
# It does not validate Dataset Build staging, `configs/data/filter-v2.yaml`, fixed Drive publish,
# archive names, or artifact acceptance. Use `tests/operational/colab_smoke_checklist.md` for
# the Dataset Build operational smoke.

# %%
# %pip install -r requirements-colab.txt

# %%
from text_to_sign_production import __version__, smoke_check

assert smoke_check() == "t2sp-smoke-ok"
print(__version__)
print(smoke_check())
